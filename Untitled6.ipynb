# %%
#1
n = int(input())
print('so gap doi cua n =', n*2)
# Out:
#  36
# so gap doi cua n = 72

# %%
#2
line = input()
a,b=map(float, line.split())
S = a*b-(a/2)**2*3.14
print(f"{S:.2f}")
# Out:
#  3 6
# 10.93

# %%
#3
c = input()
print(c.swapcase())
# Out:
#  V
# v

# %%
#4
c = input()
if c.isalpha():
    print(c,"là kí tự alphabet")
else:
    print(c,"không phải là kí tự alphabet")
# Out:
#  5
# 5 không phải là kí tự alphabet

# %%
#6
line = input()
a,b,c = map(float, line.split())
p = (a+b+c)/2
S = (p*(p-a)*(p-b)*(p-c))**0.5
if a>0 and b>0 and c>0 and (a+b)>c and (a+c)>b and (b+c)>a:
    print(f"{S:.1f}") 
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
#  -1 2 3
# Khong phai 3 canh cua tam giac

# %%
*a,b,c = input("Tên, chỉ số tháng trước, chỉ số tháng này").split()
a = " ".join(a)
b = int(b)
c = int(c)
d = (c-b)*1.08
bac1=1984*d
bac2=2050*d
bac3=2380*d
bac4=2998*d
bac5=3350*d
bac6=3460*d
if 0<=(c-b)<=50:
    print('Họ và tên:', a)
    print('Tiền phải trả là', f'{bac1:.0f}')
elif 51<=(c-b)<=100:
    print('Họ và tên:', a)
    print('Tiền phải trả là', f'{bac2:.0f}')
elif 101<=(c-b)<=200:
    print('Họ và tên:', a)
    print('Tiền phải trả là', f'{bac3:.0f}')
elif 201<=(c-b)<=300:
    print('Họ và tên:', a)
    print('Tiền phải trả là', f'{bac4:.0f}')
elif 301<=(c-b)<=400:
    print('Họ và tên:', a)
    print('Tiền phải trả là', f'{bac5:.0f}')
elif 401<=(c-b):
    print('Họ và tên:', a)
    print('Tiền phải trả là', f'{bac6:.0f}')
# Out:
# Tên, chỉ số tháng trước, chỉ số tháng này Pham Xuan Toai 1020 1070
# Họ và tên: Pham Xuan Toai
# Tiền phải trả là 107136
