# %%
#1
n = int(input())
print('so gap doi cua n =', n*2)
# Out:
#  8
# so gap doi cua n = 16

# %%
#2
line = input()
a,b=map(float, line.split())
S = a*b-(a/2)**2*3.14
print(f"{S:.2f}")
# Out:
#  3 6
# 10.93

# %%
#3
c = input()
print(c.swapcase())
# Out:
#  V
# v

# %%
#4
c = input()
if c.isalpha():
    print(c,'là kí tự alphabet')
else:
    print(c,'không phải là kí tự alphabet')
# Out:
#  5
# 5 không phải là kí tự alphabet

# %%
#5
c = input('nhập chữ cái in hoa:')
if not (c.isalpha() and c.isupper()):
    print('đây không phải chữ in hoa')
elif c == 'A':
    print('chữ a không có chữ cái trước.')
else:
    print('chữ cái thường liền trước:', chr(ord(c.lower()) - 1))
# Out:
# nhập chữ cái in hoa: P
# chữ cái thường liền trước: o

# %%
#6
line = input()
a,b,c = map(float, line.split())
p = (a+b+c)/2
S = (p*(p-a)*(p-b)*(p-c))**0.5
if a>0 and b>0 and c>0 and (a+b)>c and (a+c)>b and (b+c)>a:
    print('diện tích tam giác:', f"{S:.1f}") 
else:
    print('Khong phai 3 canh cua tam giac')
# Out:
#  6 7 8.8
# diện tích tam giác: 20.9

# %%
#7
S = input('chuỗi >=20 kí tự:')
if len(S) < 20:
    print('chưa đủ 20 kí tự')
else: 
    print('kí tự thứ 5:', S[4])
    print('kí tự thứ 7:', S[6])
# Out:
# chuỗi >=20 kí tự: abcdefghijklnmopwxyz
# kí tự thứ 5: f
# kí tự thứ 7: h

# %%
#8
*a,b,c = input("Tên, chỉ số tháng trước, chỉ số tháng này:").split()
a = " ".join(a)
b = int(b)
c = int(c)
d = (c-b)
if d <= 50:
        t = d * 1984
elif 51 <= d <= 100:
    t = (50 * 1984 + (d - 50) * 2050)*1.08
elif 101 <= d <= 200:
    t = (50 * 1984 + 50 * 2050 + (d - 100) * 2380)*1.08
elif 201<= d <= 300:
    t = (50 * 1984 + 50 * 2050 + 100 * 2380 + (d - 200) * 2998)*1.08
elif 301<= d <= 400:
    t = (50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (d - 300) * 3350)*1.08
else:
    t = (50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (d - 400) * 3460)*1.08
print('Họ và tên:', a)
print('Tiền phải trả là:', f'{t:.0f}')
# Out:
# Tên, chỉ số tháng trước, chỉ số tháng này: Nguyen Xuan Hai 2000 2586
# Họ và tên: Nguyen Xuan Hai
# Tiền phải trả là: 1855505
